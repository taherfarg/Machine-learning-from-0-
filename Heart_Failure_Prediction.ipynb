# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score

from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
data = pd.read_csv("heart_failure_dataset.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (299, 13)

# %%
data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
data.head(10)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
# 7  60.0        1                       315         1                 60
# 8  65.0        0                       157         0                 65
# 9  80.0        1                       123         0                 35
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
# 5                    1  204000.00               2.1           132    1
# 6                    0  127000.00               1.2           137    1
# 7                    0  454000.00               1.1           131    1
# 8                    0  263358.03               1.5           138    0
# 9                    1  388000.00               9.4           133    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1
# 5        1     8            1
# 6        0    10            1
# 7        1    10            1
# 8        0    10            1
# 9        1    10            1

# %%
#split our dataset into two categories to make it easier for analysis

categorical_variables = data[["anaemia","diabetes","high_blood_pressure","sex","smoking"]]
continuous_variables = data[["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium","time"]]

# %%
type(categorical_variables)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_rows', 300)
data.isna().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
continuous_variables.describe()
# Out:
#               age  creatinine_phosphokinase  ejection_fraction      platelets  \
# count  299.000000                299.000000         299.000000     299.000000
# mean    60.833893                581.839465          38.083612  263358.029264
# std     11.894809                970.287881          11.834841   97804.236869
# min     40.000000                 23.000000          14.000000   25100.000000
# 25%     51.000000                116.500000          30.000000  212500.000000
# 50%     60.000000                250.000000          38.000000  262000.000000
# 75%     70.000000                582.000000          45.000000  303500.000000
# max     95.000000               7861.000000          80.000000  850000.000000
#
#        serum_creatinine  serum_sodium        time
# count         299.00000    299.000000  299.000000
# mean            1.39388    136.625418  130.260870
# std             1.03451      4.412477   77.614208
# min             0.50000    113.000000    4.000000
# 25%             0.90000    134.000000   73.000000
# 50%             1.10000    137.000000  115.000000
# 75%             1.40000    140.000000  203.000000
# max             9.40000    148.000000  285.000000

# %%
data.groupby("DEATH_EVENT").count()
# Out:
#              age  anaemia  creatinine_phosphokinase  diabetes  \
# DEATH_EVENT
# 0            203      203                       203       203
# 1             96       96                        96        96
#
#              ejection_fraction  high_blood_pressure  platelets  \
# DEATH_EVENT
# 0                          203                  203        203
# 1                           96                   96         96
#
#              serum_creatinine  serum_sodium  sex  smoking  time
# DEATH_EVENT
# 0                         203           203  203      203   203
# 1                          96            96   96       96    96

# %%
age = data[["age"]]
platelets = data[["platelets"]]
type(data[['age']])
# Out:
# pandas.core.frame.DataFrame

# %%
#Visualizing the unbalanced data with a scatter plot, the colors will depend on DEATH_EVENT (0 or 1)

plt.figure(figsize=(13,7))
plt.scatter(platelets, age, c = data["DEATH_EVENT"], s=100, alpha=0.8)
plt.xlabel("Platelets", fontsize=20)
plt.ylabel("Age",fontsize=20)
plt.title("Visualizing the unbalanced data", fontsize=22)
plt.show()

# %%
plt.figure(figsize=(13,7))
sns.heatmap(data.corr(), vmin=-1, vmax=1, cmap="YlGnBu", annot=True)
plt.title("Relationship between all the variables of the dataset and DEATH_EVENT", fontsize = 22)
plt.show()

# %%
categorical_data = ["anaemia","diabetes","high_blood_pressure","sex","smoking"]
continuous_data = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium","time"]

# %%
# Plotting the impact of categorical variables on DEATH_EVENT

plt.figure(figsize=(13,10))
for i,cat in enumerate(categorical_data):
    plt.subplot(2,3,i+1)
    sns.countplot(data = data, x= cat, hue = "DEATH_EVENT")
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
sns.countplot(data = data, x= 'anaemia', hue = "DEATH_EVENT")
plt.subplot(2,2,4)
sns.countplot(data = data, x= 'diabetes', hue = "DEATH_EVENT")
# Out:
# <Axes: xlabel='diabetes', ylabel='count'>

# %%
for i,cat in enumerate(categorical_data):
    print(i, cat)
# Out:
# 0 anaemia
# 1 diabetes
# 2 high_blood_pressure
# 3 sex
# 4 smoking

# %%
# Plotting the impact of continuous variables on DEATH_EVENT

plt.figure(figsize=(17,15))
for j,con in enumerate(continuous_data):
    plt.subplot(3,3,j+1)
    sns.histplot(data = data, x= con, hue = "DEATH_EVENT", multiple="stack")
plt.show()

# %%
for i,cat in enumerate(continuous_data):
    print(i, cat)
# Out:
# 0 age
# 1 creatinine_phosphokinase
# 2 ejection_fraction
# 3 platelets
# 4 serum_creatinine
# 5 serum_sodium
# 6 time

# %%
sns.histplot(data = data, x= 'age', hue = "DEATH_EVENT", multiple="stack")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(8,8))
sns.boxplot(data=data, x="sex", y="age", hue="DEATH_EVENT")
plt.title("The impact of sex and age on the death event", fontsize=22)
plt.show()

# %%
# Analyzing the survival status on smoking

smokers = data[data["smoking"]==1]
non_smokers = data[data["smoking"]==0]

non_survived_smokers = smokers[smokers["DEATH_EVENT"]==1]
survived_non_smokers = non_smokers[non_smokers["DEATH_EVENT"]==0]
non_survived_non_smokers = non_smokers[non_smokers["DEATH_EVENT"]==1]
survived_smokers = smokers[smokers["DEATH_EVENT"]==0]

smoking_data = [len(non_survived_smokers), len(survived_non_smokers),len(non_survived_non_smokers),len(survived_smokers)]
smoking_labels = ["non_survived_smokers", "survived_non_smokers", "non_survived_non_smokers", "survived_smokers"]

plt.figure(figsize=(9,9))
plt.pie(smoking_data, labels = smoking_labels, autopct='%.2f%%', startangle=90)
circle = plt.Circle((0,0), 0.8, color="white")
p = plt.gcf()
p.gca().add_artist(circle)
plt.title("Survival status on smoking", fontsize=22)
plt.show()

# %%
plt.pie(smoking_data, labels = smoking_labels, autopct='%.1f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x20663f332d0>,
#   <matplotlib.patches.Wedge at 0x206647d6d50>,
#   <matplotlib.patches.Wedge at 0x206647c6a90>,
#   <matplotlib.patches.Wedge at 0x206647d7d10>],
#  [Text(-0.34101771647194173, 1.045804435376071, 'non_survived_smokers'),
#   Text(-0.9658242801224177, -0.5264821553728236, 'survived_non_smokers'),
#   Text(0.9602393822474176, -0.5366007163441904, 'non_survived_non_smokers'),
#   Text(0.7031236200758868, 0.8459415907090634, 'survived_smokers')],
#  [Text(-0.18600966353015, 0.5704387829324022, '10.0%'),
#   Text(-0.5268132437031369, -0.28717208474881284, '45.8%'),
#   Text(0.5237669357713186, -0.2926912998241038, '22.1%'),
#   Text(0.3835219745868473, 0.4614226858413072, '22.1%')])

# %%
smokers[smokers["DEATH_EVENT"]==1]
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 2    65.0        0                       146         0                 20
# 5    90.0        1                        47         0                 40
# 7    60.0        1                       315         1                 60
# 9    80.0        1                       123         0                 35
# 10   75.0        1                        81         0                 38
# 11   62.0        0                       231         0                 25
# 22   68.0        1                       220         0                 35
# 25   80.0        0                       148         1                 38
# 27   70.0        0                       122         1                 45
# 29   82.0        0                        70         1                 30
# 40   70.0        0                       582         0                 20
# 41   50.0        0                       124         1                 30
# 42   70.0        0                       571         1                 45
# 45   50.0        0                       582         1                 38
# 47   60.0        0                       582         1                 38
# 54   60.0        1                       260         1                 38
# 58   49.0        0                       789         0                 20
# 59   72.0        0                       364         1                 20
# 65   60.0        0                        68         0                 20
# 67   72.0        1                       110         0                 25
# 72   85.0        0                      5882         0                 35
# 74   69.0        0                       582         0                 20
# 75   60.0        1                        47         0                 20
# 105  72.0        1                       328         0                 30
# 110  85.0        0                       129         0                 60
# 144  72.0        1                       943         0                 25
# 181  59.0        1                       176         1                 25
# 182  65.0        0                       395         1                 25
# 184  58.0        1                       145         0                 25
# 266  55.0        0                      1199         0                 20
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 2                      0  162000.00              1.30           129    1
# 5                      1  204000.00              2.10           132    1
# 7                      0  454000.00              1.10           131    1
# 9                      1  388000.00              9.40           133    1
# 10                     1  368000.00              4.00           131    1
# 11                     1  253000.00              0.90           140    1
# 22                     1  289000.00              0.90           140    1
# 25                     0  149000.00              1.90           144    1
# 27                     1  284000.00              1.30           136    1
# 29                     0  200000.00              1.20           132    1
# 40                     1  263358.03              1.83           134    1
# 41                     1  153000.00              1.20           136    0
# 42                     1  185000.00              1.20           139    1
# 45                     0  310000.00              1.90           135    1
# 47                     1  451000.00              0.60           138    1
# 54                     0  255000.00              2.20           132    0
# 58                     1  319000.00              1.10           136    1
# 59                     1  254000.00              1.30           136    1
# 65                     0  119000.00              2.90           127    1
# 67                     0  274000.00              1.00           140    1
# 72                     0  243000.00              1.00           132    1
# 74                     0  266000.00              1.20           134    1
# 75                     0  204000.00              0.70           139    1
# 105                    1  621000.00              1.70           138    0
# 110                    0  306000.00              1.20           132    1
# 144                    1  338000.00              1.70           139    1
# 181                    0  221000.00              1.00           136    1
# 182                    0  265000.00              1.20           136    1
# 184                    0  219000.00              1.20           137    1
# 266                    0  263358.03              1.83           134    1
#
#      smoking  time  DEATH_EVENT
# 2          1     7            1
# 5          1     8            1
# 7          1    10            1
# 9          1    10            1
# 10         1    10            1
# 11         1    10            1
# 22         1    20            1
# 25         1    23            1
# 27         1    26            1
# 29         1    26            1
# 40         1    31            1
# 41         1    32            1
# 42         1    33            1
# 45         1    35            1
# 47         1    40            1
# 54         1    45            1
# 58         1    55            1
# 59         1    59            1
# 65         1    64            1
# 67         1    65            1
# 72         1    72            1
# 74         1    73            1
# 75         1    73            1
# 105        1    88            1
# 110        1    90            1
# 144        1   111            1
# 181        1   150            1
# 182        1   154            1
# 184        1   170            1
# 266        1   241            1

# %%
x = data[["age","creatinine_phosphokinase","ejection_fraction","serum_creatinine","serum_sodium","time"]]
y = data["DEATH_EVENT"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2)

# %%
# Data scaling
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
accuracy_list = []

# %%
lr_model = LogisticRegression()
lr_model.fit(x_train_scaled, y_train)
lr_prediction = lr_model.predict(x_test_scaled)
lr_accuracy = (round(accuracy_score(lr_prediction, y_test), 4) * 100) #percentage
accuracy_list.append(lr_accuracy)

# %%
svc_model = SVC()
svc_model.fit(x_train_scaled, y_train)
svc_prediction = svc_model.predict(x_test_scaled)
svc_accuracy = (round(accuracy_score(svc_prediction, y_test), 4) * 100) #percentage
accuracy_list.append(svc_accuracy)

# %%
# We use this program to find the optimal value of k
knn_list = []
for k in range(1,50):
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(x_train_scaled, y_train)
    knn_prediction = knn_model.predict(x_test_scaled)
    knn_accuracy = (round(accuracy_score(knn_prediction, y_test), 4) * 100)
    knn_list.append(knn_accuracy)
k = np.arange(1,50)
plt.plot(k, knn_list)

# %%
knn_model = KNeighborsClassifier(n_neighbors=6)
knn_model.fit(x_train_scaled, y_train)
knn_prediction = knn_model.predict(x_test_scaled)
knn_accuracy = (round(accuracy_score(knn_prediction, y_test), 4) * 100) #percentage
accuracy_list.append(knn_accuracy)

# %%
dt_model = DecisionTreeClassifier(criterion="entropy", max_depth=2)
dt_model.fit(x_train_scaled, y_train)
dt_prediction = dt_model.predict(x_test_scaled)
dt_accuracy = (round(accuracy_score(dt_prediction, y_test), 4) * 100) #percentage
accuracy_list.append(dt_accuracy)

# %%
nb_model = GaussianNB()
nb_model.fit(x_train_scaled, y_train)
nb_prediction = nb_model.predict(x_test_scaled)
nb_accuracy = (round(accuracy_score(nb_prediction, y_test), 4) * 100) #percentage
accuracy_list.append(nb_accuracy)

# %%
rf_model = RandomForestClassifier()
rf_model.fit(x_train_scaled, y_train)
rf_prediction = rf_model.predict(x_test_scaled)
rf_accuracy = (round(accuracy_score(rf_prediction, y_test), 4) * 100) #percentage
accuracy_list.append(rf_accuracy)

# %%
accuracy_list
# Out:
# [87.78, 84.44, 84.44, 88.89, 82.22, 85.56]

# %%
models = ["Logistic Regression","SVC","KNearestNeighbors","Decision Tree","Naive Bayes","Random Forest"]

# %%
plt.figure(figsize=(12,7))
ax = sns.barplot(x=models, y=accuracy_list)
plt.xlabel("Classifiers", fontsize=15)
plt.ylabel("Accuracy (%)", fontsize=15)
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x = p.get_x()
    y = p.get_y()
    ax.annotate(f"{height} %", (x + width/2, y+ height*1.01), ha="center")
plt.show()

# %%
#nueron network
x = data[["age","creatinine_phosphokinase","ejection_fraction","serum_creatinine","serum_sodium","time"]]
y = data["DEATH_EVENT"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2)

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

mlp_model = MLPClassifier(hidden_layer_sizes=(100,100,100), max_iter=500)
mlp_model.fit(x_train_scaled, y_train)
mlp_prediction = mlp_model.predict(x_test_scaled)
mlp_accuracy = (round(accuracy_score(mlp_prediction, y_test), 4) * 100) #percentage
accuracy_list.append(mlp_accuracy)

# %%
#anthor neuron network with keras 
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Define the features and target variables
x = data[["age","creatinine_phosphokinase","ejection_fraction","serum_creatinine","serum_sodium","time"]]
y = data["DEATH_EVENT"]

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2)

# Scale the features
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# Create and train the MLP classifier
mlp_model = MLPClassifier(hidden_layer_sizes=(100,100,100), max_iter=500)
mlp_model.fit(x_train_scaled, y_train)

# Make predictions on the test set
mlp_prediction = mlp_model.predict(x_test_scaled)

# Calculate the accuracy of the model
mlp_accuracy = round(accuracy_score(mlp_prediction, y_test) * 100, 2)

# Print the accuracy
print("Accuracy of the MLP classifier: {}%".format(mlp_accuracy))
# Out:
# Accuracy of the MLP classifier: 83.33%

# %%
#anthor neuron network with tensorflow and keras 

import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Define the features and target variables
x = data[["age","creatinine_phosphokinase","ejection_fraction","serum_creatinine","serum_sodium","time"]]
y = data["DEATH_EVENT"]

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2)

# Reset the indices of the training data
x_train.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)

# Scale the features
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# Create and train the MLP classifier
mlp_model = keras.models.Sequential([
    keras.layers.Dense(100, activation='relu', input_shape=(x_train.shape[1],)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])
mlp_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
mlp_model.fit(x_train_scaled, y_train, epochs=100)

# Make predictions on the test set
mlp_prediction = mlp_model.predict(x_test_scaled)
mlp_prediction = np.round(mlp_prediction)

# Calculate the accuracy of the model
mlp_accuracy = round(accuracy_score(mlp_prediction, y_test) * 100, 2)

# Print the accuracy
print("Accuracy of the MLP classifier: {}%".format(mlp_accuracy))
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 4ms/step - loss: 0.6572 - accuracy: 0.6459
# Epoch 2/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5578 - accuracy: 0.7895
# Epoch 3/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4549 - accuracy: 0.8038
# Epoch 4/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4018 - accuracy: 0.8134
# Epoch 5/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3799 - accuracy: 0.8086
# Epoch 6/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3507 - accuracy: 0.8373
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3374 - accuracy: 0.8469
# Epoch 8/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3233 - accuracy: 0.8517
# Epoch 9/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3054 - accuracy: 0.8612
# Epoch 10/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2813 - accuracy: 0.8708
# Epoch 11/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2617 - accuracy: 0.8900
# Epoch 12/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2497 - accuracy: 0.8995
# Epoch 13/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2296 - accuracy: 0.8995
# Epoch 14/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2191 - accuracy: 0.9043
# Epoch 15/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1995 - accuracy: 0.9187
# Epoch 16/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1780 - accuracy: 0.9234
# Epoch 17/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1586 - accuracy: 0.9330
# Epoch 18/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1449 - accuracy: 0.9378
# Epoch 19/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1250 - accuracy: 0.9569
# Epoch 20/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1101 - accuracy: 0.9761
# Epoch 21/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0966 - accuracy: 0.9761
# Epoch 22/100
# 7/7 [==============================] - 0s 856us/step - loss: 0.0833 - accuracy: 0.9856
# Epoch 23/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0833 - accuracy: 0.9761
# Epoch 24/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 0.9665
# Epoch 25/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0879 - accuracy: 0.9665
# Epoch 26/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0765 - accuracy: 0.9665
# Epoch 27/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0491 - accuracy: 0.9856
# Epoch 28/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0406 - accuracy: 0.9952
# Epoch 29/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0324 - accuracy: 0.9952
# Epoch 30/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 0.9952
# Epoch 31/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 0.9761
# Epoch 32/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0490 - accuracy: 0.9856
# Epoch 33/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 34/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9952
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 36/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 37/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 38/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 39/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 40/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 41/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 42/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 43/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 44/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 45/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 46/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 47/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 48/100
# 7/7 [==============================] - 0s 0s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 49/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 50/100
# 7/7 [==============================] - 0s 181us/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 51/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 52/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 53/100
# 7/7 [==============================] - 0s 3ms/step - loss: 9.6456e-04 - accuracy: 1.0000
# Epoch 54/100
# 7/7 [==============================] - 0s 3ms/step - loss: 8.8388e-04 - accuracy: 1.0000
# Epoch 55/100
# 7/7 [==============================] - 0s 3ms/step - loss: 8.1827e-04 - accuracy: 1.0000
# Epoch 56/100
# 7/7 [==============================] - 0s 3ms/step - loss: 7.8252e-04 - accuracy: 1.0000
# Epoch 57/100
# 7/7 [==============================] - 0s 2ms/step - loss: 7.5007e-04 - accuracy: 1.0000
# Epoch 58/100
# 7/7 [==============================] - 0s 3ms/step - loss: 6.9486e-04 - accuracy: 1.0000
# Epoch 59/100
# 7/7 [==============================] - 0s 3ms/step - loss: 6.5421e-04 - accuracy: 1.0000
# Epoch 60/100
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0656e-04 - accuracy: 1.0000
# Epoch 61/100
# 7/7 [==============================] - 0s 2ms/step - loss: 5.6535e-04 - accuracy: 1.0000
# Epoch 62/100
# 7/7 [==============================] - 0s 3ms/step - loss: 5.3315e-04 - accuracy: 1.0000
# Epoch 63/100
# 7/7 [==============================] - 0s 3ms/step - loss: 5.0571e-04 - accuracy: 1.0000
# Epoch 64/100
# 7/7 [==============================] - 0s 3ms/step - loss: 4.7550e-04 - accuracy: 1.0000
# Epoch 65/100
# 7/7 [==============================] - 0s 3ms/step - loss: 4.5385e-04 - accuracy: 1.0000
# Epoch 66/100
# 7/7 [==============================] - 0s 3ms/step - loss: 4.3475e-04 - accuracy: 1.0000
# Epoch 67/100
# 7/7 [==============================] - 0s 3ms/step - loss: 4.1420e-04 - accuracy: 1.0000
# Epoch 68/100
# 7/7 [==============================] - 0s 3ms/step - loss: 3.9053e-04 - accuracy: 1.0000
# Epoch 69/100
# 7/7 [==============================] - 0s 2ms/step - loss: 3.6860e-04 - accuracy: 1.0000
# Epoch 70/100
# 7/7 [==============================] - 0s 3ms/step - loss: 3.5357e-04 - accuracy: 1.0000
# Epoch 71/100
# 7/7 [==============================] - 0s 3ms/step - loss: 3.3543e-04 - accuracy: 1.0000
# Epoch 72/100
# 7/7 [==============================] - 0s 6ms/step - loss: 3.1741e-04 - accuracy: 1.0000
# Epoch 73/100
# 7/7 [==============================] - 0s 2ms/step - loss: 3.0577e-04 - accuracy: 1.0000
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - loss: 2.9340e-04 - accuracy: 1.0000
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: 2.8237e-04 - accuracy: 1.0000
# Epoch 76/100
# 7/7 [==============================] - 0s 2ms/step - loss: 2.7137e-04 - accuracy: 1.0000
# Epoch 77/100
# 7/7 [==============================] - 0s 2ms/step - loss: 2.5484e-04 - accuracy: 1.0000
# Epoch 78/100
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4283e-04 - accuracy: 1.0000
# Epoch 79/100
# 7/7 [==============================] - 0s 3ms/step - loss: 2.3237e-04 - accuracy: 1.0000
# Epoch 80/100
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2219e-04 - accuracy: 1.0000
# Epoch 81/100
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1653e-04 - accuracy: 1.0000
# Epoch 82/100
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0543e-04 - accuracy: 1.0000
# Epoch 83/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.9724e-04 - accuracy: 1.0000
# Epoch 84/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9237e-04 - accuracy: 1.0000
# Epoch 85/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8104e-04 - accuracy: 1.0000
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7608e-04 - accuracy: 1.0000
# Epoch 87/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6722e-04 - accuracy: 1.0000
# Epoch 88/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6140e-04 - accuracy: 1.0000
# Epoch 89/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5951e-04 - accuracy: 1.0000
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5356e-04 - accuracy: 1.0000
# Epoch 91/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4483e-04 - accuracy: 1.0000
# Epoch 92/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3897e-04 - accuracy: 1.0000
# Epoch 93/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3548e-04 - accuracy: 1.0000
# Epoch 94/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3179e-04 - accuracy: 1.0000
# Epoch 95/100
# 7/7 [==============================] - 0s 84us/step - loss: 1.2666e-04 - accuracy: 1.0000
# Epoch 96/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2252e-04 - accuracy: 1.0000
# Epoch 97/100
# 7/7 [==============================] - 0s 541us/step - loss: 1.1838e-04 - accuracy: 1.0000
# Epoch 98/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1454e-04 - accuracy: 1.0000
# Epoch 99/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1048e-04 - accuracy: 1.0000
# Epoch 100/100
# 7/7 [==============================] - 0s 190us/step - loss: 1.0704e-04 - accuracy: 1.0000
# 3/3 [==============================] - 0s 0s/step
# Accuracy of the MLP classifier: 81.11%

# %%
#predict using linear regression model 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Define the features and target variables
x = data[["age","creatinine_phosphokinase","ejection_fraction","serum_creatinine","serum_sodium","time"]]
y = data["DEATH_EVENT"]

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2)

# Scale the features
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# Create and train the linear regression model
from sklearn.linear_model import LinearRegression

# Create and train the linear regression model
linear_model = LinearRegression()
linear_model.fit(x_train_scaled, y_train)

# Make predictions on the test set
linear_prediction = linear_model.predict(x_test_scaled)
linear_prediction = np.round(linear_prediction)

# Calculate the accuracy of the model
linear_accuracy = round(accuracy_score(linear_prediction, y_test) * 100, 2)

# Print the accuracy
print("Accuracy of the Linear regression model: {}%".format(linear_accuracy))
# Out:
# Accuracy of the Linear regression model: 87.78%

# %%
accuracy_list
# Out:
# [87.78, 84.44, 84.44, 88.89, 82.22, 85.56, 80.0]
